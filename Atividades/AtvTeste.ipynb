// %% [markdown]
// # Atividade teste

// %% [markdown]
// Gere uma saída de texto entre aspas duplas, criando uma nova linha e posicionando o cursor na linha abaixo.

// %%
/*IFPR - Campus Cascavel
 Disciplina: Programação Orientada á Objetos
 Professor: Nelson Bellincanta  
 Aluno: Matheus Zimmermann 
 3 Informatica */

public class TextAspasDuplas{
    
    //execucao do programa com o metodo 'main' //
    public static void main(String[] args)
    {
        //gera uma string de texto, cria uma nova linha e então posiciona o cursor abaixo da linha atual//
        System.out.println("Texto");
        
    }//fim do metodo main//
    
}//finaliza a classe criada "TextAspasDuplas"//
// Out:
// com.twosigma.beaker.javash.bkrab9449bb.TextAspasDuplas
